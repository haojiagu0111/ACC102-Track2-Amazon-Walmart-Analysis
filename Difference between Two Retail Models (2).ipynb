# %% [markdown]
# # Financial Performance Comparison: Online vs Offline Retail
# ## ACC102 Mini Assignment Track 2
# Amazon (AMZN) & Walmart (WMT) | 2015-2025

# %% [markdown]
# ## 1. Project Overview
# This project compares financial performance differences between **online e-commerce Amazon (AMZN)** and traditional offline physical retailer Walmart (WMT).
# Four core financial indicators are analysed:
# - Total Revenue
# - Net Income
# - Net Profit Margin
# - Year-on-Year Revenue Growth Rate
#
# Data source: WRDS Compustat Database, sample period: 2015-2025

# %%
import wrds
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# ## 2. Data Acquisition
# Connect to WRDS database and extract annual financial statement data of two listed companies.

# %%
username = "haojiagu0111"
db = wrds.Connection(wrds_username=username)
# Out:
# Loading library list...
# Done

# %% [markdown]
# ## 3. Financial Indicator Calculation
# 1. Convert date format and extract annual data
# 2. Net Profit Margin = Net Income / Total Revenue
# 3. YoY Revenue Growth = (Current Revenue - Previous Revenue) / Previous Revenue

# %%
data = db.raw_sql("""
    SELECT
        gvkey,
        tic,
        conm,
        datadate,
        csho,
        sale,
        ni,
        rect,
        at
    FROM
        comp.funda
    WHERE
        tic IN ('AMZN','WMT')
        AND datadate >= '2014-01-01'
        AND datadate <= '2025-12-31'
        AND datafmt = 'STD'
        AND indfmt = 'INDL'
        AND popsrc = 'D'
    ORDER BY
        tic, datadate
""")

data
# Out:
#      gvkey   tic            conm    datadate      csho      sale       ni  \
# 0   064768  AMZN  AMAZON.COM INC  2014-12-31     465.0   88988.0   -241.0
# 1   064768  AMZN  AMAZON.COM INC  2015-12-31     471.0  107006.0    596.0
# 2   064768  AMZN  AMAZON.COM INC  2016-12-31     477.0  135987.0   2371.0
# 3   064768  AMZN  AMAZON.COM INC  2017-12-31     484.0  177866.0   3033.0
# 4   064768  AMZN  AMAZON.COM INC  2018-12-31     491.0  232887.0  10073.0
# 5   064768  AMZN  AMAZON.COM INC  2019-12-31     498.0  280522.0  11588.0
# 6   064768  AMZN  AMAZON.COM INC  2020-12-31     503.0  386064.0  21331.0
# 7   064768  AMZN  AMAZON.COM INC  2021-12-31     509.0  469822.0  33364.0
# 8   064768  AMZN  AMAZON.COM INC  2022-12-31   10242.0  513983.0  -2722.0
# 9   064768  AMZN  AMAZON.COM INC  2023-12-31   10383.0  574785.0  30425.0
# 10  064768  AMZN  AMAZON.COM INC  2024-12-31   10593.0  637959.0  59248.0
# 11  064768  AMZN  AMAZON.COM INC  2025-12-31   10731.0  716924.0  77670.0
# 12  011259   WMT     WALMART INC  2014-01-31    3233.0  474259.0  16022.0
# 13  011259   WMT     WALMART INC  2015-01-31    3228.0  483521.0  16363.0
# 14  011259   WMT     WALMART INC  2016-01-31    3162.0  479962.0  14694.0
# 15  011259   WMT     WALMART INC  2017-01-31    3048.0  482154.0  13643.0
# 16  011259   WMT     WALMART INC  2018-01-31    2952.0  496785.0   9862.0
# 17  011259   WMT     WALMART INC  2019-01-31    2878.0  511729.0   6670.0
# 18  011259   WMT     WALMART INC  2020-01-31  2832.493  521426.0  14881.0
# 19  011259   WMT     WALMART INC  2021-01-31    2821.0  556933.0  13510.0
# 20  011259   WMT     WALMART INC  2022-01-31    2761.0  569962.0  13673.0
# 21  011259   WMT     WALMART INC  2023-01-31    2693.0  608481.0  11680.0
# 22  011259   WMT     WALMART INC  2024-01-31    2685.0  645737.0  15511.0
# 23  011259   WMT     WALMART INC  2025-01-31    8024.0  678338.0  19436.0
#
#        rect        at
# 0    3300.0   54505.0
# 1    4400.0   65444.0
# 2    6561.0   83402.0
# 3    9692.0  131310.0
# 4   13310.0  162648.0
# 5   17663.0  225248.0
# 6   19981.0  321195.0
# 7   26500.0  420549.0
# 8   34800.0  462675.0
# 9   46900.0  527854.0
# 10  49300.0  624894.0
# 11  60800.0  818042.0
# 12   6677.0  204751.0
# 13   6778.0  203706.0
# 14   5624.0  199581.0
# 15   5835.0  198825.0
# 16   5614.0  204522.0
# 17   6283.0  219295.0
# 18   6284.0  236495.0
# 19   6516.0  252496.0
# 20   8280.0  244860.0
# 21   7933.0  243197.0
# 22   8796.0  252399.0
# 23   9975.0  260823.0

# %% [markdown]
# ## 4. Visual Analysis

# %%
data['datadate'] = pd.to_datetime(data['datadate'], errors='coerce')
data['year'] = data['datadate'].dt.year
data['net_margin'] = data['ni'] / data['sale']
data['rev_growth'] = data.groupby('tic')['sale'].pct_change()
result = data[['tic','year','conm','sale','ni','net_margin','rev_growth']]
print(result)
# Out:
#      tic  year            conm      sale       ni  net_margin  rev_growth
# 0   AMZN  2014  AMAZON.COM INC   88988.0   -241.0   -0.002708        <NA>
# 1   AMZN  2015  AMAZON.COM INC  107006.0    596.0     0.00557    0.202477
# 2   AMZN  2016  AMAZON.COM INC  135987.0   2371.0    0.017435    0.270835
# 3   AMZN  2017  AMAZON.COM INC  177866.0   3033.0    0.017052    0.307963
# 4   AMZN  2018  AMAZON.COM INC  232887.0  10073.0    0.043253     0.30934
# 5   AMZN  2019  AMAZON.COM INC  280522.0  11588.0    0.041309    0.204541
# 6   AMZN  2020  AMAZON.COM INC  386064.0  21331.0    0.055252    0.376234
# 7   AMZN  2021  AMAZON.COM INC  469822.0  33364.0    0.071014    0.216954
# 8   AMZN  2022  AMAZON.COM INC  513983.0  -2722.0   -0.005296    0.093995
# 9   AMZN  2023  AMAZON.COM INC  574785.0  30425.0    0.052933    0.118296
# 10  AMZN  2024  AMAZON.COM INC  637959.0  59248.0    0.092871    0.109909
# 11  AMZN  2025  AMAZON.COM INC  716924.0  77670.0    0.108338    0.123778
# 12   WMT  2014     WALMART INC  474259.0  16022.0    0.033783        <NA>
# 13   WMT  2015     WALMART INC  483521.0  16363.0    0.033841    0.019529
# 14   WMT  2016     WALMART INC  479962.0  14694.0    0.030615   -0.007361
# 15   WMT  2017     WALMART INC  482154.0  13643.0    0.028296    0.004567
# 16   WMT  2018     WALMART INC  496785.0   9862.0    0.019852    0.030345
# 17   WMT  2019     WALMART INC  511729.0   6670.0    0.013034    0.030081
# 18   WMT  2020     WALMART INC  521426.0  14881.0    0.028539    0.018949
# 19   WMT  2021     WALMART INC  556933.0  13510.0    0.024258    0.068096
# 20   WMT  2022     WALMART INC  569962.0  13673.0    0.023989    0.023394
# 21   WMT  2023     WALMART INC  608481.0  11680.0    0.019195    0.067582
# 22   WMT  2024     WALMART INC  645737.0  15511.0    0.024021    0.061228
# 23   WMT  2025     WALMART INC  678338.0  19436.0    0.028652    0.050486

# %%
plt.style.use('default')

# %% [markdown]
# ## 4. Visual Analysis: Annual Revenue Trend

# %%
plt.figure(figsize=(12,5))
for tic in data['tic'].unique():
    df = data[data['tic']==tic]
    plt.plot(df['year'], df['sale'], marker='o', ms=6, label=df['conm'].iloc[0])
    

plt.axvline(x=2020, color='red', linestyle='--')
plt.title('Revenue Trend (2015–2025): Amazon vs Walmart')
plt.xlabel('Year')
plt.ylabel('Revenue')
plt.legend()
plt.grid(alpha=0.3)
plt.xlim(2015, 2025)
plt.show()

# %% [markdown]
# ## 4. Visual Analysis: Net Income Trend

# %%
plt.figure(figsize=(12,5))
for tic in data['tic'].unique():
    df = data[data['tic']==tic]
    plt.plot(df['year'], df['ni'], marker='s', ms=6, label=df['conm'].iloc[0])

plt.axvline(x=2020, color='red', linestyle='--')
plt.title('Net Income Trend (2015–2025)')
plt.xlabel('Year')
plt.ylabel('Net Income')
plt.legend()
plt.grid(alpha=0.3)
plt.xlim(2015, 2025)
plt.show()

# %% [markdown]
# ## 4. Visual Analysis: Net Margin Trend

# %%
plt.figure(figsize=(12,5))
for tic in data['tic'].unique():
    df = data[data['tic']==tic]
    plt.plot(df['year'], df['net_margin'], marker='d', ms=6, label=df['conm'].iloc[0])

plt.axvline(x=2020, color='red', linestyle='--')
plt.title('Net Margin (2015–2025)')
plt.xlabel('Year')
plt.ylabel('Net Margin')
plt.legend()
plt.grid(alpha=0.3)
plt.xlim(2015, 2025)
plt.show()

# %% [markdown]
# ## 4. Visual Analysis: Revenue Growth Trend

# %%
plt.figure(figsize=(12,5))
for tic in data['tic'].unique():
    df = data[data['tic']==tic]
    plt.plot(df['year'], df['rev_growth'], marker='^', ms=6, label=df['conm'].iloc[0])

plt.axvline(x=2020, color='red', linestyle='--')
plt.title('Revenue Growth Rate (YoY) (2015–2025)')
plt.xlabel('Year')
plt.ylabel('Growth Rate')
plt.legend()
plt.grid(alpha=0.3)
plt.xlim(2015, 2025)
plt.show()

# %%
db.close()

# %% [markdown]
# ## 5. Conclusion
# 1. Amazon online retail has higher revenue growth and greater profit volatility
# 2. Walmart offline retail maintains stable low growth and steady cash flow
# 3. COVID-19 pandemic in 2020 significantly widened the performance gap between online and offline retail industry
